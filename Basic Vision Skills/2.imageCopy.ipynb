# %%
import cv2
from google.colab.patches import cv2_imshow

# OpenCV 버전을 확인합니다
print("OpenCV version:")
print(cv2.__version__)

# 이미지를 읽어 옵니다.
img = cv2.imread("rear_garden.PNG")
print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
 
# 이미지를 Display 합니다.
cv2_imshow(img)
# Out:
# OpenCV version:
# 4.1.2
# width: 819 pixels
# height: 496 pixels
# channels: 3
# <PIL.Image.Image image mode=RGB size=819x496 at 0x7FA46B80AF98>

# %%
img.shape
# Out:
# (496, 819, 3)

# %%
# 이미지를 복사합니다.
cv2.imwrite("rear_garden.jpg", img)
# Out:
# True
