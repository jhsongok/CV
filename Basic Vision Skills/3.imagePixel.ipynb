# %%
import cv2
from google.colab.patches import cv2_imshow

# OpenCV 버전을 확인합니다
print("OpenCV version:")
print(cv2.__version__)

# 이미지를 읽어 옵니다. 
img = cv2.imread("rear_garden.PNG")
print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
 
# 이미지를 Display 합니다.
cv2_imshow(img)
# Out:
# OpenCV version:
# 4.1.2
# width: 819 pixels
# height: 496 pixels
# channels: 3
# <PIL.Image.Image image mode=RGB size=819x496 at 0x7F00A7499978>

# %%
# 이미지의 특정 위치 = 픽셀(Pixel), Pixel(BGB)
(b, g, r) = img[0, 0]
print("Pixel at (0, 0) - Red: {}, Green: {}, Blue: {}".format(r, g, b))
# Out:
# Pixel at (0, 0) - Red: 8, Green: 20, Blue: 18

# %%
# 이미지에서 특정한 범위만 지정하여 Display
ROI = img[50:100, 50:100]
cv2_imshow(ROI)
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F7CBD023E48>

# %%
# 이미지 내에서 특정한 범위만 지정하여 색상을 변경
img[50:100, 50:100] = (0, 0, 255)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=819x496 at 0x7F7CBD023E10>
