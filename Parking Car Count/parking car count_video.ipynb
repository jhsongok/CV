# %%
# 내 구글 드라이브에 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 필요한 패키지와 모듈을 불러옴
import cv2
import numpy as np
import time
import io
import base64
from IPython.display import HTML

# %%
# Detection 하기 전에 원본 동영상을 Display
video = io.open('gdrive/My Drive/CV/Parking Car Count/video/parking.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video width="30%" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4"/>
             </video>'''.format(encoded.decode('ascii')))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
file_name = 'gdrive/My Drive/CV/Parking Car Count/video/parking.mp4'  # Detection 할 원본 동영상
min_confidence = 0.5   # detection 으로 인정할 최소 확률(신뢰도) 지정
output_name = 'parking_car_count_video.mp4'  # Detection 된 output 동영상
elapsed_time = 0       # 총 경과시간 초기화

# %%
def detectAndDisplay(frame):
    start_time = time.time()
    img = cv2.resize(frame, None, fx=0.9, fy=0.9)
    height, width, channels = img.shape

    # YOLOv3의 Detecting model 3가지(320×320, 416×416, 608×608)
    blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)

    # Showing informations on the screen
    confidences = []    # detection 한 Class 의 신뢰도(확률)를 저장하는 배열 정의
    boxes = []          # detection 한 boxing 정보를 저장하는 배열 정의

    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)      # detection 한 Class id
            confidence = scores[class_id]     # detection 한 Class 의 신뢰도(확률)
            # Filter only 'car'
            if class_id == 2 and confidence > min_confidence:
                # Object detected
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # Rectangle coordinates
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])             # boxing 정보를 boxes 배열에 저장
                confidences.append(float(confidence))  # 신뢰도(확률)을 confidences 배열에 저장
    
    # apply non-max suppression
    indexes = cv2.dnn.NMSBoxes(boxes, confidences, min_confidence, 0.4)    # 박스안에 박스(노이즈)를 하나로 만들어 준다.
    font = cv2.FONT_HERSHEY_PLAIN
    for i in range(len(boxes)):
        if i in indexes:    # 노이즈가 제거된 박스만 표시해 준다.   
            x, y, w, h = boxes[i]
            label = '{:,.2%}'.format(confidences[i])  # 신뢰도(확률) 
            print(i, label)
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 1)
            cv2.rectangle(img, (x, y - 20), (x + w, y), (0, 255, 0), -1)
            cv2.putText(img, label, (x + 5, y - 5), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 1)

    text = "number of parked cars : {} ".format(len(indexes))
    cv2.putText(img, text, (40, 40), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 0), 10)
    cv2.putText(img, text, (40, 40), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)
 
    process_time = time.time() - start_time
    global elapsed_time
    elapsed_time += process_time   # 총 경과시간 누적
    print("=== A frame took {:.3f} seconds".format(process_time))

    # video 를 disk 에 output 하기 위해 writer 를 초기화한다.
    global writer
    if writer is None and output_name is not None:
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter(output_name, fourcc, 30,
                (img.shape[1], img.shape[0]), True)
        
    # disk 에 frame 을 write 합니다.
    if writer is not None:
        writer.write(img)

# %%
# Load Yolo
net = cv2.dnn.readNet("gdrive/My Drive/CV/Object Detection_YOLO/yolov3.weights", "gdrive/My Drive/CV/Object Detection_YOLO/yolov3.cfg")  
classes = []  # detection 할 Object(Class) list 배열을 정의
with open("gdrive/My Drive/CV/Object Detection_YOLO/coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]   # 80개의 Object(class)를 구분할 수 있는 Object의 이름을 classes 배열에 넣어준다.
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# 원본 동영상에서 video stream을 읽어온다.
cap = cv2.VideoCapture(file_name)
writer = None
if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)
while True:
    ret, frame = cap.read()
    if frame is None:
        # close the video file pointers
        cap.release()
        # close the writer point
        writer.release()
        print('--(!) No captured frame -- Break!')
        print("elapsed time {:.3f} seconds".format(elapsed_time))
        break
    detectAndDisplay(frame)
# Out:
# 0 99.72%
# 1 70.29%
# 3 50.54%
# === A frame took 2.232 seconds
# 0 99.68%
# 1 77.13%
# 3 59.65%
# === A frame took 2.051 seconds
# 0 55.18%
# 1 99.72%
# 2 77.87%
# === A frame took 2.024 seconds
# 0 56.65%
# 1 99.72%
# 2 76.52%
# === A frame took 2.020 seconds
# 0 62.22%
# 1 99.74%
# 2 77.52%
# === A frame took 2.028 seconds
# 0 73.42%
# 1 99.78%
# 2 70.60%
# === A frame took 2.036 seconds
# 0 77.82%
# 1 99.84%
# 2 82.11%
# === A frame took 2.019 seconds
# 0 70.41%
# 1 99.81%
# 2 70.74%
# === A frame took 2.038 seconds
# 0 74.03%
# 1 99.78%
# 2 68.17%
# === A frame took 2.046 seconds
# 0 73.08%
# 1 99.74%
# 2 69.01%
# === A frame took 2.011 seconds
# 0 76.57%
# 1 99.75%
# 2 80.25%
# === A frame took 2.012 seconds
# 0 75.17%
# 1 99.78%
# 2 71.60%
# === A frame took 2.016 seconds
# 0 71.29%
# 1 99.80%
# 2 68.05%
# 4 52.78%
# === A frame took 2.020 seconds
# 0 71.98%
# 1 99.84%
# 2 64.53%
# 4 64.22%
# === A frame took 1.988 seconds
# 0 59.66%
# 1 99.88%
# 2 73.13%
# === A frame took 2.011 seconds
# 0 60.74%
# 1 99.77%
# 2 80.71%
# === A frame took 2.001 seconds
# 0 65.92%
# 1 99.75%
# 2 77.65%
# === A frame took 2.002 seconds
# 0 59.67%
# 1 99.70%
# 2 75.26%
# === A frame took 1.996 seconds
# 0 52.60%
# 1 99.66%
# 2 75.66%
# === A frame took 1.974 seconds
# 0 50.91%
# 1 99.60%
# 2 68.71%
# === A frame took 1.964 seconds
# 0 64.22%
# 1 99.60%
# 2 77.15%
# === A frame took 1.969 seconds
# 0 77.22%
# 1 99.62%
# 2 76.11%
# === A frame took 1.966 seconds
# 0 66.23%
# 1 99.60%
# 2 71.44%
# === A frame took 1.957 seconds
# 0 99.28%
# 1 72.33%
# === A frame took 1.946 seconds
# 0 99.47%
# 1 78.68%
# === A frame took 1.928 seconds
# 0 64.79%
# 1 99.62%
# 2 78.93%
# 4 55.09%
# === A frame took 1.962 seconds
# 0 61.84%
# 1 99.54%
# 2 75.69%
# === A frame took 1.943 seconds
# 0 69.56%
# 1 99.46%
# 2 69.89%
# === A frame took 1.914 seconds
# 0 77.32%
# 1 99.54%
# 2 76.08%
# === A frame took 1.930 seconds
# 0 79.20%
# 1 99.61%
# 2 78.94%
# === A frame took 1.944 seconds
# 0 50.72%
# 1 99.43%
# 2 82.17%
# === A frame took 1.931 seconds
# 0 99.39%
# 1 80.08%
# === A frame took 1.985 seconds
# 0 99.30%
# 1 77.99%
# === A frame took 1.929 seconds
# 0 99.33%
# 1 80.32%
# === A frame took 1.917 seconds
# 0 51.50%
# 1 99.46%
# 2 80.30%
# === A frame took 1.937 seconds
# 0 99.46%
# 1 76.17%
# === A frame took 1.955 seconds
# 0 62.87%
# 1 99.42%
# 2 82.70%
# === A frame took 1.948 seconds
# 0 62.57%
# 1 99.46%
# 2 84.96%
# === A frame took 1.943 seconds
# 0 66.43%
# 1 99.43%
# 2 82.99%
# === A frame took 1.957 seconds
# 0 69.29%
# 1 99.47%
# 2 83.95%
# === A frame took 1.952 seconds
# 0 66.43%
# 1 99.36%
# 2 81.43%
# === A frame took 1.901 seconds
# 0 71.46%
# 1 99.42%
# 2 82.13%
# === A frame took 1.914 seconds
# 0 71.59%
# 1 99.44%
# 2 83.32%
# === A frame took 1.949 seconds
# 0 70.22%
# 1 99.41%
# 2 80.38%
# === A frame took 1.937 seconds
# 0 74.66%
# 1 99.49%
# 2 76.42%
# === A frame took 1.925 seconds
# 0 71.56%
# 1 99.55%
# 2 74.06%
# === A frame took 1.914 seconds
# 0 73.07%
# 1 99.58%
# 2 77.69%
# === A frame took 1.933 seconds
# 0 70.89%
# 1 99.62%
# 2 71.03%
# === A frame took 1.920 seconds
# 0 74.06%
# 1 99.68%
# 2 77.26%
# === A frame took 1.961 seconds
# 0 75.41%
# 1 99.67%
# 2 83.44%
# === A frame took 1.906 seconds
# 0 71.78%
# 1 99.62%
# 2 79.56%
# === A frame took 1.906 seconds
# 0 77.80%
# 1 99.57%
# 2 79.97%
# === A frame took 1.932 seconds
# 0 74.08%
# 1 99.63%
# 2 78.12%
# === A frame took 1.912 seconds
# 0 69.69%
# 1 99.68%
# 2 78.92%
# === A frame took 1.919 seconds
# 0 65.41%
# 1 99.79%
# 2 81.32%
# 4 50.19%
# === A frame took 1.912 seconds
# 0 70.42%
# 1 99.80%
# 2 83.78%
# 4 51.73%
# === A frame took 1.927 seconds
# 0 72.86%
# 1 99.75%
# 2 82.97%
# === A frame took 1.932 seconds
# 0 69.70%
# 1 99.77%
# 2 79.40%
# === A frame took 1.919 seconds
# 0 66.12%
# 1 99.72%
# 2 82.82%
# === A frame took 1.932 seconds
# 0 75.74%
# 1 99.77%
# 2 78.83%
# === A frame took 1.864 seconds
# 0 79.79%
# 1 99.78%
# 2 78.52%
# 4 53.15%
# === A frame took 1.902 seconds
# 0 79.94%
# 1 99.75%
# 2 71.95%
# === A frame took 1.895 seconds
# 0 75.32%
# 1 99.67%
# 2 73.55%
# === A frame took 1.895 seconds
# 0 65.98%
# 1 99.73%
# 2 68.73%
# 4 52.76%
# === A frame took 1.890 seconds
# 0 99.78%
# 1 72.36%
# 3 54.54%
# === A frame took 1.882 seconds
# 0 99.77%
# 1 64.75%
# === A frame took 1.919 seconds
# 0 99.60%
# 1 58.72%
# === A frame took 1.949 seconds
# 0 51.62%
# 1 99.73%
# 2 59.70%
# === A frame took 1.898 seconds
# 0 99.72%
# 1 66.61%
# === A frame took 1.913 seconds
# 0 60.47%
# 1 99.74%
# 2 69.11%
# === A frame took 1.910 seconds
# 0 52.22%
# 1 99.80%
# 2 73.39%
# === A frame took 1.945 seconds
# 0 68.29%
# 1 99.80%
# 2 76.64%
# === A frame took 1.911 seconds
# 0 99.85%
# 1 82.83%
# === A frame took 1.923 seconds
# 0 73.69%
# 1 99.81%
# 2 83.37%
# === A frame took 1.904 seconds
# 0 67.74%
# 1 99.86%
# 2 77.32%
# === A frame took 1.898 seconds
# 0 78.38%
# 1 99.84%
# 2 79.09%
# === A frame took 1.930 seconds
# 0 78.36%
# 1 99.86%
# 2 82.88%
# === A frame took 1.891 seconds
# 0 64.83%
# 1 99.87%
# 2 80.58%
# === A frame took 1.895 seconds
# 0 82.69%
# 1 99.86%
# 2 78.29%
# === A frame took 1.913 seconds
# 0 87.62%
# 1 99.82%
# 2 82.28%
# 3 55.18%
# === A frame took 1.876 seconds
# 0 85.34%
# 1 99.82%
# 2 77.49%
# 3 60.77%
# 5 57.24%
# === A frame took 1.903 seconds
# 0 90.44%
# 1 99.83%
# 2 79.67%
# 3 54.34%
# === A frame took 1.885 seconds
# 0 88.80%
# 1 99.83%
# 2 78.66%
# 3 65.24%
# === A frame took 1.939 seconds
# 0 86.79%
# 1 99.78%
# 2 66.22%
# 3 54.66%
# 5 55.22%
# === A frame took 1.891 seconds
# 0 86.69%
# 1 99.73%
# 2 65.15%
# 4 51.44%
# === A frame took 1.925 seconds
# 0 83.34%
# 1 99.79%
# 2 64.31%
# === A frame took 1.893 seconds
# 0 73.98%
# 1 99.77%
# 2 63.90%
# 4 52.24%
# === A frame took 1.874 seconds
# 0 51.51%
# 1 99.68%
# 2 65.98%
# === A frame took 1.892 seconds
# 0 71.66%
# 1 99.62%
# 2 61.49%
# === A frame took 1.886 seconds
# 0 99.65%
# 1 55.55%
# === A frame took 1.886 seconds
# 0 99.06%
# 1 51.21%
# === A frame took 1.871 seconds
# 0 98.45%
# 1 75.93%
# === A frame took 1.879 seconds
# 0 99.20%
# 1 84.81%
# === A frame took 1.895 seconds
# 0 99.57%
# 1 93.21%
# === A frame took 1.885 seconds
# 0 99.56%
# 1 90.48%
# === A frame took 1.874 seconds
# 0 98.78%
# 1 93.50%
# === A frame took 1.897 seconds
# 0 99.16%
# 1 91.29%
# === A frame took 1.901 seconds
# 0 58.72%
# 1 99.22%
# 2 76.97%
# === A frame took 1.891 seconds
# 0 99.46%
# 1 84.09%
# === A frame took 1.938 seconds
# 0 99.36%
# 1 88.87%
# === A frame took 1.914 seconds
# 0 98.42%
# 1 78.36%
# === A frame took 1.891 seconds
# 0 75.27%
# 1 99.13%
# 2 77.17%
# 4 60.59%
# === A frame took 1.916 seconds
# 0 99.53%
# 1 83.62%
# 3 68.26%
# === A frame took 1.914 seconds
# 0 99.74%
# 1 79.73%
# === A frame took 1.894 seconds
# 0 99.72%
# 1 72.29%
# === A frame took 1.981 seconds
# 0 53.45%
# 1 99.62%
# 2 64.18%
# === A frame took 1.993 seconds
# 0 67.13%
# 1 99.66%
# 2 63.42%
# === A frame took 1.917 seconds
# 0 70.45%
# 1 99.61%
# 2 71.39%
# === A frame took 1.904 seconds
# 0 52.56%
# 1 99.55%
# 2 74.51%
# === A frame took 1.881 seconds
# 0 60.22%
# 1 99.69%
# 2 83.43%
# 3 60.81%
# === A frame took 1.890 seconds
# 0 99.73%
# 1 84.65%
# === A frame took 1.870 seconds
# 0 99.81%
# 1 83.70%
# 3 62.44%
# === A frame took 1.871 seconds
# 0 57.10%
# 1 99.83%
# 2 85.65%
# === A frame took 1.892 seconds
# 0 73.20%
# 1 99.83%
# 2 86.14%
# === A frame took 1.889 seconds
# 0 73.26%
# 1 99.82%
# 2 80.00%
# 4 52.75%
# === A frame took 1.895 seconds
# 0 67.34%
# 1 99.79%
# 2 85.99%
# 4 58.63%
# === A frame took 1.897 seconds
# 0 54.39%
# 1 99.78%
# 2 86.04%
# 4 60.68%
# === A frame took 1.858 seconds
# 0 57.43%
# 1 99.84%
# 2 85.61%
# 4 77.71%
# === A frame took 1.849 seconds
# 0 99.82%
# 1 89.71%
# 3 89.21%
# === A frame took 1.866 seconds
# 0 99.82%
# 1 91.62%
# 3 84.52%
# === A frame took 1.865 seconds
# 0 67.16%
# 1 99.81%
# 2 91.68%
# 4 91.83%
# === A frame took 1.909 seconds
# 0 64.25%
# 1 99.82%
# 2 89.63%
# 3 57.01%
# 5 91.39%
# === A frame took 1.858 seconds
# 0 61.44%
# 1 99.82%
# 2 91.93%
# 3 55.41%
# 5 84.25%
# === A frame took 1.853 seconds
# 0 74.26%
# 1 99.83%
# 2 91.91%
# 3 52.53%
# 5 86.44%
# === A frame took 1.870 seconds
# 0 78.20%
# 1 99.85%
# 2 86.59%
# 4 93.92%
# === A frame took 1.876 seconds
# 0 80.07%
# 1 99.87%
# 2 90.85%
# 4 94.83%
# === A frame took 1.871 seconds
# 0 80.16%
# 1 99.82%
# 4 95.70%
# 5 92.31%
# === A frame took 1.859 seconds
# 0 78.92%
# 1 99.88%
# 4 96.18%
# 5 92.47%
# === A frame took 1.864 seconds
# 0 79.55%
# 1 99.88%
# 4 95.97%
# 5 90.55%
# === A frame took 1.838 seconds
# 0 86.90%
# 1 99.86%
# 4 93.00%
# 5 87.90%
# === A frame took 1.897 seconds
# 0 81.68%
# 1 99.87%
# 2 86.87%
# 4 94.60%
# === A frame took 1.863 seconds
# 0 97.30%
# 1 96.76%
# 2 97.62%
# 3 93.64%
# === A frame took 1.834 seconds
# 0 97.78%
# 1 96.78%
# 2 97.56%
# 3 93.03%
# === A frame took 1.815 seconds
# 0 97.36%
# 1 96.09%
# 2 96.84%
# 3 93.97%
# === A frame took 1.829 seconds
# 0 97.09%
# 1 96.30%
# 2 96.53%
# 3 91.88%
# === A frame took 1.896 seconds
# 0 97.10%
# 1 97.29%
# 2 95.83%
# 3 85.40%
# === A frame took 1.934 seconds
# 0 97.26%
# 1 97.04%
# 2 96.43%
# 3 90.79%
# === A frame took 1.884 seconds
# 0 97.59%
# 1 96.56%
# 2 95.81%
# 3 91.48%
# === A frame took 1.900 seconds
# 0 95.99%
# 1 95.02%
# 2 95.82%
# 3 91.90%
# 5 55.26%
# === A frame took 1.917 seconds
# 0 96.34%
# 1 95.42%
# 2 95.91%
# 3 94.83%
# 5 55.74%
# === A frame took 1.887 seconds
# 0 96.23%
# 1 96.09%
# 2 94.77%
# 3 90.67%
# 5 51.42%
# === A frame took 1.888 seconds
# 0 97.08%
# 1 96.82%
# 2 94.23%
# 3 90.68%
# === A frame took 1.875 seconds
# 0 96.34%
# 1 96.63%
# 2 94.88%
# 3 91.73%
# 5 63.50%
# === A frame took 1.841 seconds
# 0 96.68%
# 1 96.93%
# 2 94.61%
# 3 88.88%
# 5 66.39%
# === A frame took 1.891 seconds
# 0 97.26%
# 1 97.00%
# 2 96.52%
# 3 93.79%
# 5 56.18%
# === A frame took 1.885 seconds
# 0 97.20%
# 1 96.94%
# 2 95.76%
# 3 93.23%
# === A frame took 1.927 seconds
# 0 97.65%
# 1 96.93%
# 2 97.06%
# 3 93.28%
# 5 62.14%
# === A frame took 1.896 seconds
# 0 98.17%
# 1 97.29%
# 2 97.16%
# 3 91.02%
# 5 61.63%
# === A frame took 1.890 seconds
# 0 98.14%
# 1 97.49%
# 2 97.69%
# 3 95.29%
# 5 69.89%
# === A frame took 1.891 seconds
# 0 98.39%
# 1 96.18%
# 2 96.70%
# 3 89.71%
# 5 60.97%
# === A frame took 1.874 seconds
# 0 98.35%
# 1 95.34%
# 2 97.00%
# 3 92.32%
# 5 62.77%
# === A frame took 1.881 seconds
# 0 98.10%
# 1 94.51%
# 2 97.23%
# 3 88.98%
# 5 61.30%
# === A frame took 1.907 seconds
# 0 96.78%
# 1 94.57%
# 2 96.69%
# 3 91.03%
# 5 54.30%
# === A frame took 1.921 seconds
# 0 97.38%
# 1 95.32%
# 2 96.99%
# 3 84.47%
# === A frame took 1.875 seconds
# 0 97.31%
# 1 95.07%
# 2 97.52%
# 3 83.91%
# 5 51.35%
# === A frame took 1.873 seconds
# 0 97.16%
# 1 94.23%
# 2 97.42%
# 3 88.67%
# 5 57.90%
# === A frame took 1.856 seconds
# 0 97.35%
# 1 92.37%
# 2 97.27%
# 3 90.56%
# 5 54.35%
# === A frame took 1.861 seconds
# 0 97.81%
# 1 90.77%
# 2 97.43%
# 3 92.81%
# 5 50.56%
# === A frame took 1.826 seconds
# 0 97.55%
# 1 94.09%
# 2 52.71%
# 3 97.73%
# 4 91.33%
# === A frame took 1.827 seconds
# 0 97.62%
# 1 94.63%
# 2 96.96%
# 3 92.94%
# === A frame took 1.854 seconds
# 0 98.47%
# 1 93.04%
# 2 96.44%
# 3 91.73%
# === A frame took 1.860 seconds
# 0 96.81%
# 1 94.84%
# 2 50.67%
# 3 95.70%
# 4 87.55%
# === A frame took 1.867 seconds
# 0 95.02%
# 1 93.78%
# 2 51.86%
# 3 93.96%
# 4 86.68%
# === A frame took 1.881 seconds
# 0 96.69%
# 1 94.33%
# 2 54.31%
# 3 94.64%
# 4 87.78%
# === A frame took 1.897 seconds
# 0 95.70%
# 1 92.41%
# 2 95.16%
# 3 93.54%
# === A frame took 1.873 seconds
# 0 96.17%
# 1 93.73%
# 2 50.11%
# 3 95.60%
# 4 92.85%
# === A frame took 1.842 seconds
# 0 96.93%
# 1 94.55%
# 2 95.72%
# 3 94.14%
# === A frame took 1.873 seconds
# 0 97.44%
# 1 94.67%
# 2 96.47%
# 3 92.96%
# === A frame took 1.901 seconds
# 0 98.28%
# 1 95.05%
# 2 96.81%
# 3 92.51%
# === A frame took 1.858 seconds
# 0 98.62%
# 1 93.53%
# 2 97.35%
# 3 88.88%
# === A frame took 1.839 seconds
# 0 98.96%
# 1 91.91%
# 2 97.68%
# 3 93.44%
# === A frame took 1.910 seconds
# 0 98.60%
# 1 89.37%
# 2 97.10%
# 3 95.47%
# === A frame took 1.854 seconds
# 0 98.68%
# 1 85.47%
# 2 96.98%
# 3 95.10%
# === A frame took 1.867 seconds
# 0 98.45%
# 1 81.78%
# 2 97.47%
# 3 95.45%
# === A frame took 1.846 seconds
# 0 98.87%
# 1 88.95%
# 2 97.12%
# 3 96.27%
# === A frame took 1.868 seconds
# 0 98.93%
# 1 90.60%
# 2 96.85%
# 3 95.55%
# === A frame took 1.895 seconds
# 0 98.97%
# 1 90.66%
# 2 97.55%
# 3 96.42%
# === A frame took 1.912 seconds
# 0 98.99%
# 1 87.12%
# 2 96.91%
# 3 93.54%
# === A frame took 1.904 seconds
# 0 98.60%
# 1 89.51%
# 2 96.75%
# 3 92.59%
# === A frame took 1.902 seconds
# 0 98.84%
# 1 77.39%
# 2 96.88%
# 3 92.85%
# === A frame took 1.890 seconds
# 0 98.65%
# 1 90.30%
# 2 97.11%
# 3 93.77%
# === A frame took 1.919 seconds
# 0 98.80%
# 1 85.73%
# 2 96.90%
# 3 93.72%
# === A frame took 1.880 seconds
# 0 98.56%
# 1 89.08%
# 2 97.44%
# 3 94.38%
# === A frame took 1.854 seconds
# 0 98.65%
# 1 89.06%
# 2 97.79%
# 3 94.77%
# === A frame took 1.866 seconds
# 0 98.76%
# 1 86.56%
# 2 52.23%
# 3 96.71%
# 4 94.05%
# === A frame took 1.828 seconds
# 0 98.97%
# 1 87.36%
# 2 53.98%
# 3 97.39%
# 4 93.31%
# === A frame took 1.866 seconds
# 0 98.93%
# 1 90.81%
# 2 50.84%
# 3 97.40%
# 4 93.82%
# === A frame took 1.859 seconds
# 0 98.92%
# 1 91.80%
# 2 65.88%
# 3 98.01%
# 4 95.57%
# === A frame took 1.858 seconds
# 0 98.74%
# 1 92.01%
# 2 56.49%
# 3 97.37%
# 4 96.42%
# === A frame took 1.919 seconds
# 0 98.99%
# 1 94.28%
# 2 97.81%
# 3 96.86%
# === A frame took 1.839 seconds
# 0 98.94%
# 1 95.55%
# 2 97.86%
# 3 95.17%
# === A frame took 1.833 seconds
# 0 98.25%
# 1 93.54%
# 2 96.97%
# 3 92.88%
# === A frame took 1.837 seconds
# 0 98.60%
# 1 93.07%
# 2 97.11%
# 3 92.91%
# === A frame took 1.851 seconds
# 0 97.71%
# 1 95.34%
# 2 97.76%
# 3 95.28%
# === A frame took 1.810 seconds
# 0 98.23%
# 1 94.09%
# 2 97.31%
# 3 96.75%
# === A frame took 1.815 seconds
# 0 97.98%
# 1 96.19%
# 2 56.81%
# 3 97.53%
# 4 95.71%
# === A frame took 1.796 seconds
# 0 97.61%
# 1 93.75%
# 2 98.30%
# 3 95.10%
# === A frame took 1.798 seconds
# 0 97.78%
# 1 96.77%
# 2 97.51%
# 3 92.94%
# === A frame took 1.854 seconds
# 0 97.99%
# 1 96.63%
# 2 98.13%
# 3 94.87%
# === A frame took 1.824 seconds
# 0 98.03%
# 1 96.98%
# 2 58.35%
# 3 97.38%
# 4 94.72%
# === A frame took 1.843 seconds
# 0 97.85%
# 1 95.86%
# 2 98.11%
# 3 58.42%
# 4 93.52%
# === A frame took 1.895 seconds
# 0 98.12%
# 1 94.47%
# 2 54.96%
# 3 98.32%
# 4 93.08%
# === A frame took 2.014 seconds
# 0 98.16%
# 1 96.18%
# 2 51.67%
# 3 98.07%
# 4 92.19%
# === A frame took 1.920 seconds
# 0 98.23%
# 1 96.85%
# 2 50.01%
# 3 98.62%
# 4 96.32%
# === A frame took 1.773 seconds
# 0 98.74%
# 1 96.07%
# 2 98.90%
# 3 95.51%
# === A frame took 1.815 seconds
# 0 98.70%
# 1 95.79%
# 2 98.26%
# 3 94.89%
# === A frame took 1.741 seconds
# 0 98.69%
# 1 95.99%
# 2 98.81%
# 3 95.81%
# === A frame took 1.739 seconds
# 0 98.84%
# 1 89.67%
# 2 69.45%
# 3 98.32%
# 4 96.52%
# === A frame took 1.753 seconds
# 0 98.83%
# 1 89.47%
# 2 71.09%
# 3 98.15%
# 4 93.90%
# === A frame took 1.755 seconds
# 0 98.25%
# 1 88.32%
# 2 70.56%
# 3 98.16%
# 4 94.16%
# === A frame took 1.743 seconds
# 0 97.36%
# 1 89.16%
# 2 72.82%
# 3 98.55%
# 4 93.30%
# === A frame took 1.745 seconds
# 0 98.00%
# 1 91.93%
# 2 73.31%
# 3 98.64%
# 4 94.23%
# === A frame took 1.825 seconds
# 0 97.34%
# 1 90.65%
# 2 70.24%
# 3 98.30%
# 4 93.73%
# === A frame took 1.742 seconds
# 0 97.29%
# 1 90.73%
# 2 60.07%
# 3 98.07%
# 4 93.15%
# === A frame took 1.773 seconds
# 0 97.47%
# 1 91.65%
# 2 54.83%
# 3 98.10%
# 4 93.87%
# === A frame took 1.747 seconds
# 0 97.08%
# 1 90.48%
# 2 97.96%
# 3 93.90%
# === A frame took 1.775 seconds
# 0 97.24%
# 1 91.63%
# 2 97.77%
# 3 93.07%
# === A frame took 1.776 seconds
# 0 96.20%
# 1 88.10%
# 2 97.38%
# 3 91.49%
# === A frame took 1.798 seconds
# 0 97.11%
# 1 89.30%
# 2 97.07%
# 3 87.80%
# === A frame took 1.762 seconds
# 0 96.78%
# 1 84.08%
# 2 98.04%
# 3 88.35%
# === A frame took 1.812 seconds
# 0 96.81%
# 1 92.36%
# 2 98.06%
# 3 89.83%
# === A frame took 1.794 seconds
# 0 96.46%
# 1 89.21%
# 2 98.18%
# 3 92.06%
# === A frame took 1.843 seconds
# 0 96.34%
# 1 92.94%
# 2 98.76%
# 3 96.14%
# === A frame took 1.844 seconds
# 0 97.57%
# 1 95.88%
# 2 98.67%
# 3 94.76%
# === A frame took 1.847 seconds
# 0 97.43%
# 1 94.00%
# 2 98.02%
# 3 90.13%
# === A frame took 1.876 seconds
# 0 97.51%
# 1 95.71%
# 2 97.74%
# 3 91.20%
# === A frame took 1.913 seconds
# 0 97.53%
# 1 99.25%
# 2 99.81%
# === A frame took 1.833 seconds
# 0 84.25%
# 1 99.30%
# 2 99.80%
# === A frame took 1.914 seconds
# 0 90.25%
# 1 99.07%
# 2 99.79%
# === A frame took 1.848 seconds
# 0 94.40%
# 1 98.90%
# 2 99.83%
# === A frame took 1.807 seconds
# 0 96.12%
# 1 99.52%
# 2 99.85%
# === A frame took 1.817 seconds
# 0 95.91%
# 1 99.39%
# 2 99.86%
# === A frame took 1.797 seconds
# 0 92.54%
# 1 99.42%
# 2 99.86%
# === A frame took 1.827 seconds
# 0 86.52%
# 1 99.15%
# 2 99.87%
# === A frame took 1.828 seconds
# 0 93.27%
# 1 99.24%
# 2 99.85%
# === A frame took 1.876 seconds
# 0 91.08%
# 1 99.43%
# 2 99.84%
# === A frame took 1.824 seconds
# 0 89.76%
# 1 99.44%
# 2 99.87%
# === A frame took 1.818 seconds
# 0 94.35%
# 1 99.41%
# 2 99.85%
# === A frame took 1.860 seconds
# 0 91.77%
# 1 99.45%
# 2 99.82%
# === A frame took 1.854 seconds
# 0 91.03%
# 1 99.37%
# 2 99.83%
# === A frame took 1.883 seconds
# 0 93.18%
# 1 99.33%
# 2 99.85%
# === A frame took 1.859 seconds
# 0 92.07%
# 1 99.24%
# 2 99.85%
# === A frame took 1.796 seconds
# 0 94.82%
# 1 99.31%
# 2 99.86%
# === A frame took 1.816 seconds
# 0 97.47%
# 1 99.59%
# 2 99.86%
# === A frame took 1.802 seconds
# 0 93.66%
# 1 99.03%
# 2 99.81%
# === A frame took 1.816 seconds
# 0 90.15%
# 1 99.42%
# 2 99.82%
# === A frame took 1.834 seconds
# 0 90.89%
# 1 99.23%
# 2 99.83%
# === A frame took 1.827 seconds
# 0 94.11%
# 1 99.33%
# 2 99.83%
# === A frame took 1.852 seconds
# 0 92.01%
# 1 99.34%
# 2 99.83%
# === A frame took 1.829 seconds
# 0 95.53%
# 1 99.44%
# 2 99.84%
# === A frame took 1.824 seconds
# 0 95.70%
# 1 99.48%
# 2 99.81%
# === A frame took 1.835 seconds
# 0 95.53%
# 1 99.37%
# 2 99.87%
# === A frame took 1.817 seconds
# 0 95.35%
# 1 99.30%
# 2 99.83%
# === A frame took 1.878 seconds
# 0 84.91%
# 1 99.50%
# 2 99.80%
# === A frame took 1.864 seconds
# 0 94.33%
# 1 99.42%
# 2 99.83%
# === A frame took 1.852 seconds
# 0 95.94%
# 1 99.67%
# 2 99.78%
# === A frame took 1.837 seconds
# 0 97.72%
# 1 99.76%
# 2 99.83%
# === A frame took 1.834 seconds
# 0 96.09%
# 1 99.75%
# 2 99.85%
# === A frame took 1.831 seconds
# 0 98.39%
# 1 99.68%
# 2 99.81%
# === A frame took 1.820 seconds
# 0 98.08%
# 1 99.72%
# 2 99.84%
# === A frame took 1.834 seconds
# 0 98.47%
# 1 99.75%
# 2 99.83%
# === A frame took 1.846 seconds
# 0 98.41%
# 1 99.70%
# 2 99.80%
# === A frame took 1.866 seconds
# 0 98.72%
# 1 99.69%
# 2 99.81%
# === A frame took 1.856 seconds
# 0 98.20%
# 1 99.80%
# 2 99.85%
# === A frame took 1.851 seconds
# 0 98.54%
# 1 99.78%
# 2 99.86%
# === A frame took 1.847 seconds
# 0 98.20%
# 1 99.84%
# 2 99.85%
# === A frame took 1.906 seconds
# 0 98.96%
# 1 99.83%
# 2 99.85%
# === A frame took 1.855 seconds
# 0 99.17%
# 1 99.76%
# 2 99.85%
# === A frame took 1.854 seconds
# 0 99.28%
# 1 99.81%
# 2 99.88%
# === A frame took 1.872 seconds
# 0 99.28%
# 1 99.86%
# 2 99.85%
# === A frame took 1.885 seconds
# 0 99.20%
# 1 99.81%
# 2 99.87%
# === A frame took 1.883 seconds
# 0 99.38%
# 1 99.86%
# 2 99.92%
# === A frame took 1.899 seconds
# 0 99.39%
# 1 99.86%
# 2 99.91%
# === A frame took 1.863 seconds
# 0 99.10%
# 1 99.81%
# 2 99.90%
# === A frame took 1.882 seconds
# 0 99.35%
# 1 99.87%
# 2 99.91%
# === A frame took 1.850 seconds
# 0 98.60%
# 1 99.81%
# 2 99.87%
# === A frame took 1.887 seconds
# 0 99.38%
# 1 99.87%
# 2 99.90%
# === A frame took 1.887 seconds
# 0 98.99%
# 1 99.87%
# 2 99.90%
# === A frame took 1.864 seconds
# 0 97.63%
# 1 99.82%
# 2 99.89%
# === A frame took 1.899 seconds
# 0 95.41%
# 1 99.63%
# 2 99.85%
# === A frame took 1.835 seconds
# 0 92.85%
# 1 99.38%
# 2 99.85%
# === A frame took 1.893 seconds
# 0 97.93%
# 1 99.45%
# 2 99.85%
# === A frame took 1.852 seconds
# 0 97.29%
# 1 99.49%
# 2 99.84%
# === A frame took 1.844 seconds
# 0 99.13%
# 1 99.56%
# 2 99.86%
# === A frame took 1.855 seconds
# 0 99.27%
# 1 99.51%
# 2 99.82%
# === A frame took 1.867 seconds
# 0 99.32%
# 1 99.67%
# 2 99.83%
# === A frame took 1.887 seconds
# 0 92.54%
# 1 99.43%
# 2 99.71%
# === A frame took 1.881 seconds
# 0 93.25%
# 1 99.50%
# 2 99.69%
# === A frame took 1.887 seconds
# 0 91.00%
# 1 99.35%
# 2 99.72%
# === A frame took 1.880 seconds
# 0 91.30%
# 1 99.17%
# 2 99.74%
# === A frame took 1.851 seconds
# 0 97.64%
# 1 98.93%
# 2 99.74%
# === A frame took 1.868 seconds
# 0 92.87%
# 1 98.95%
# 2 99.73%
# === A frame took 1.838 seconds
# 0 94.96%
# 1 99.47%
# 2 99.79%
# === A frame took 1.914 seconds
# 0 97.28%
# 1 99.34%
# 2 99.77%
# === A frame took 1.858 seconds
# 0 93.40%
# 1 99.13%
# 2 99.79%
# === A frame took 1.900 seconds
# 0 93.03%
# 1 99.22%
# 2 99.77%
# === A frame took 1.857 seconds
# 0 97.41%
# 1 99.30%
# 2 99.75%
# === A frame took 1.866 seconds
# 0 95.55%
# 1 98.92%
# 2 99.77%
# === A frame took 1.890 seconds
# 0 97.61%
# 1 99.22%
# 2 99.72%
# === A frame took 1.867 seconds
# 0 98.44%
# 1 99.51%
# 2 99.74%
# === A frame took 1.888 seconds
# 0 98.35%
# 1 99.51%
# 2 99.76%
# === A frame took 1.878 seconds
# 0 98.63%
# 1 91.57%
# 2 51.75%
# 3 98.83%
# 4 98.95%
# === A frame took 1.886 seconds
# 0 98.81%
# 1 93.15%
# 2 52.80%
# 3 98.82%
# 4 70.05%
# 5 99.00%
# === A frame took 1.867 seconds
# 0 98.61%
# 1 91.45%
# 2 53.41%
# 3 98.73%
# 4 69.16%
# 5 98.97%
# === A frame took 1.860 seconds
# 0 98.81%
# 1 91.12%
# 2 50.68%
# 3 98.89%
# 4 73.90%
# 5 99.06%
# === A frame took 1.901 seconds
# 0 99.11%
# 1 93.79%
# 2 58.85%
# 3 98.87%
# 4 72.62%
# 5 99.21%
# === A frame took 1.960 seconds
# 0 99.09%
# 1 94.06%
# 2 55.05%
# 3 98.72%
# 4 76.53%
# 5 99.15%
# === A frame took 1.902 seconds
# 0 99.12%
# 1 93.74%
# 2 61.04%
# 3 98.49%
# 4 79.56%
# 5 99.19%
# === A frame took 1.865 seconds
# 0 99.17%
# 1 94.51%
# 2 59.23%
# 3 97.94%
# 4 77.51%
# 5 99.22%
# === A frame took 1.889 seconds
# 0 99.13%
# 1 93.31%
# 2 54.68%
# 3 98.15%
# 4 74.93%
# 5 99.23%
# === A frame took 1.870 seconds
# 0 99.16%
# 1 93.63%
# 2 56.59%
# 3 98.59%
# 4 66.54%
# 5 99.16%
# === A frame took 1.890 seconds
# 0 99.32%
# 1 94.70%
# 2 55.31%
# 3 98.60%
# 4 69.75%
# 5 99.26%
# === A frame took 1.896 seconds
# 0 99.13%
# 1 93.70%
# 2 64.27%
# 3 98.44%
# 4 50.52%
# 5 99.19%
# === A frame took 1.903 seconds
# 0 99.08%
# 1 93.68%
# 2 57.22%
# 3 98.27%
# 4 59.05%
# 5 99.21%
# === A frame took 1.907 seconds
# 0 99.00%
# 1 93.95%
# 2 62.17%
# 3 98.34%
# 4 57.53%
# 5 99.11%
# === A frame took 1.904 seconds
# 0 99.10%
# 1 95.73%
# 2 61.86%
# 3 98.37%
# 4 63.69%
# 5 99.23%
# === A frame took 1.912 seconds
# 0 98.93%
# 1 95.90%
# 2 67.03%
# 3 98.24%
# 4 74.01%
# 5 99.31%
# === A frame took 1.876 seconds
# 0 99.07%
# 1 95.54%
# 2 66.74%
# 3 98.74%
# 4 73.74%
# 5 99.25%
# === A frame took 1.876 seconds
# 0 98.99%
# 1 94.88%
# 2 63.66%
# 3 98.37%
# 4 68.45%
# 5 99.28%
# === A frame took 1.873 seconds
# 0 99.05%
# 1 95.32%
# 2 62.37%
# 3 98.33%
# 4 80.34%
# 5 99.32%
# === A frame took 1.892 seconds
# 0 99.06%
# 1 95.72%
# 2 59.15%
# 3 97.74%
# 4 78.95%
# 5 99.31%
# === A frame took 1.896 seconds
# 0 99.01%
# 1 95.33%
# 2 66.64%
# 3 97.75%
# 4 75.29%
# 5 99.29%
# === A frame took 1.880 seconds
# 0 99.11%
# 1 96.13%
# 2 59.92%
# 3 97.81%
# 4 77.82%
# 5 99.37%
# === A frame took 1.912 seconds
# 0 99.09%
# 1 96.19%
# 2 63.19%
# 3 97.49%
# 4 66.72%
# 5 99.39%
# === A frame took 1.870 seconds
# 0 98.93%
# 1 95.61%
# 2 62.92%
# 3 97.46%
# 4 57.58%
# 5 99.36%
# === A frame took 1.897 seconds
# 0 99.11%
# 1 95.89%
# 2 63.08%
# 3 97.80%
# 4 69.72%
# 5 99.44%
# === A frame took 1.878 seconds
# 0 98.98%
# 1 94.91%
# 2 60.62%
# 3 97.30%
# 4 65.43%
# 5 99.35%
# === A frame took 1.899 seconds
# 0 98.89%
# 1 95.17%
# 2 56.83%
# 3 97.50%
# 4 69.77%
# 5 99.29%
# === A frame took 1.899 seconds
# 0 98.88%
# 1 94.94%
# 2 63.39%
# 3 97.68%
# 4 63.40%
# 5 99.26%
# === A frame took 1.861 seconds
# 0 98.80%
# 1 95.00%
# 2 54.28%
# 3 98.12%
# 4 80.89%
# 5 99.29%
# === A frame took 1.898 seconds
# 0 98.92%
# 1 95.08%
# 2 56.97%
# 3 97.67%
# 4 81.84%
# 5 99.31%
# === A frame took 1.915 seconds
# 0 98.74%
# 1 93.51%
# 3 64.01%
# 4 98.77%
# 6 75.56%
# 7 99.47%
# === A frame took 1.870 seconds
# 0 98.69%
# 1 92.58%
# 3 66.05%
# 4 98.39%
# 5 68.41%
# 6 99.38%
# === A frame took 1.886 seconds
# 0 98.91%
# 1 92.93%
# 2 61.59%
# 3 98.48%
# 4 57.94%
# 5 99.42%
# === A frame took 1.864 seconds
# 0 99.07%
# 1 93.80%
# 2 70.10%
# 3 98.52%
# 4 63.66%
# 5 99.41%
# === A frame took 1.872 seconds
# 0 98.79%
# 1 91.21%
# 2 64.53%
# 3 98.22%
# 4 59.84%
# 5 99.34%
# === A frame took 1.870 seconds
# 0 98.53%
# 1 88.26%
# 2 57.14%
# 3 98.34%
# 4 66.13%
# 5 99.37%
# === A frame took 1.903 seconds
# 0 98.47%
# 1 88.11%
# 2 66.22%
# 3 98.02%
# 4 66.87%
# 5 99.22%
# === A frame took 1.922 seconds
# 0 98.78%
# 1 91.65%
# 3 65.48%
# 4 98.13%
# 5 72.07%
# 6 99.34%
# === A frame took 1.933 seconds
# 0 98.69%
# 1 90.09%
# 3 64.06%
# 4 98.41%
# 5 75.11%
# 6 99.35%
# === A frame took 1.924 seconds
# 0 98.71%
# 1 92.12%
# 3 66.19%
# 4 98.47%
# 5 72.20%
# 6 99.37%
# === A frame took 1.941 seconds
# 0 98.50%
# 1 90.46%
# 3 57.48%
# 4 57.88%
# 5 98.48%
# 6 99.17%
# === A frame took 1.964 seconds
# 0 98.67%
# 1 91.38%
# 2 98.65%
# 3 61.09%
# 4 99.17%
# === A frame took 1.910 seconds
# 0 98.39%
# 1 90.20%
# 2 58.63%
# 3 98.58%
# 4 65.99%
# 5 99.20%
# === A frame took 1.944 seconds
# 0 98.48%
# 1 90.33%
# 3 58.01%
# 4 98.67%
# 5 61.85%
# 6 99.18%
# === A frame took 1.914 seconds
# 0 98.72%
# 1 91.15%
# 3 54.54%
# 4 98.61%
# 5 64.14%
# 6 99.23%
# === A frame took 1.906 seconds
# 0 98.65%
# 1 90.90%
# 3 59.96%
# 4 98.64%
# 5 71.37%
# 6 99.14%
# === A frame took 1.881 seconds
# 0 98.11%
# 1 87.79%
# 2 53.11%
# 3 62.03%
# 4 98.48%
# 5 99.04%
# === A frame took 1.864 seconds
# 0 97.92%
# 1 86.91%
# 2 58.72%
# 3 58.06%
# 4 98.41%
# 5 98.88%
# === A frame took 1.848 seconds
# 0 98.02%
# 1 86.07%
# 3 58.79%
# 4 60.07%
# 5 98.53%
# 6 98.98%
# === A frame took 1.923 seconds
# 0 98.61%
# 1 89.12%
# 2 62.53%
# 3 53.88%
# 4 98.08%
# 5 99.25%
# === A frame took 1.861 seconds
# 0 98.21%
# 1 87.00%
# 2 63.77%
# 3 56.56%
# 4 98.01%
# 5 99.29%
# === A frame took 1.903 seconds
# 0 98.44%
# 1 88.50%
# 3 63.07%
# 4 98.49%
# 5 59.69%
# 6 99.36%
# === A frame took 1.834 seconds
# 0 97.86%
# 1 86.52%
# 2 65.82%
# 3 56.34%
# 4 98.37%
# 5 99.11%
# === A frame took 1.861 seconds
# 0 97.88%
# 1 85.75%
# 2 51.12%
# 3 63.46%
# 4 98.48%
# 5 99.13%
# === A frame took 1.894 seconds
# 0 98.18%
# 1 87.33%
# 2 53.07%
# 3 63.57%
# 5 98.42%
# 6 99.16%
# === A frame took 1.866 seconds
# 0 98.54%
# 1 88.75%
# 2 62.51%
# 3 60.75%
# 4 98.43%
# 5 99.32%
# === A frame took 1.868 seconds
# 0 98.42%
# 1 88.18%
# 2 58.75%
# 3 98.62%
# 4 99.27%
# === A frame took 1.888 seconds
# 0 98.46%
# 1 90.08%
# 2 52.88%
# 3 74.93%
# 4 98.67%
# 5 99.37%
# === A frame took 1.911 seconds
# 0 98.50%
# 1 90.10%
# 2 52.23%
# 3 72.48%
# 4 98.65%
# 5 99.44%
# === A frame took 1.862 seconds
# 0 98.34%
# 1 87.59%
# 2 77.17%
# 3 98.70%
# 4 99.38%
# === A frame took 1.858 seconds
# 0 98.80%
# 1 91.61%
# 2 52.47%
# 3 66.58%
# 4 98.67%
# 5 99.43%
# === A frame took 1.876 seconds
# 0 98.67%
# 1 90.79%
# 2 51.42%
# 3 65.57%
# 4 98.79%
# 5 99.32%
# === A frame took 1.858 seconds
# 0 98.67%
# 1 91.55%
# 2 68.35%
# 3 98.63%
# 4 99.32%
# === A frame took 1.883 seconds
# 0 98.23%
# 1 88.78%
# 2 71.00%
# 3 98.66%
# 4 99.17%
# === A frame took 1.916 seconds
# 0 97.64%
# 1 85.82%
# 2 52.94%
# 3 66.64%
# 4 98.71%
# 5 98.95%
# === A frame took 1.880 seconds
# 0 97.37%
# 1 85.16%
# 2 50.29%
# 3 65.83%
# 4 98.44%
# 5 98.96%
# === A frame took 1.856 seconds
# 0 96.96%
# 1 84.98%
# 2 54.07%
# 3 62.25%
# 4 97.97%
# 5 99.02%
# === A frame took 1.903 seconds
# 0 96.61%
# 1 86.18%
# 2 54.85%
# 3 67.89%
# 4 98.40%
# 5 98.90%
# === A frame took 1.866 seconds
# 0 97.44%
# 1 88.11%
# 2 51.49%
# 3 82.07%
# 4 98.42%
# 5 99.24%
# === A frame took 1.872 seconds
# 0 97.31%
# 1 86.93%
# 2 76.89%
# 3 98.52%
# 4 99.16%
# === A frame took 1.885 seconds
# 0 97.09%
# 1 85.02%
# 2 81.16%
# 3 98.78%
# 4 99.18%
# === A frame took 1.922 seconds
# 0 97.31%
# 1 86.27%
# 2 86.86%
# 3 98.15%
# 4 99.13%
# === A frame took 1.913 seconds
# 0 97.32%
# 1 85.68%
# 3 52.92%
# 4 71.23%
# 5 98.43%
# 6 99.13%
# === A frame took 1.850 seconds
# 0 97.58%
# 1 86.61%
# 2 80.62%
# 3 98.14%
# 4 99.21%
# === A frame took 1.858 seconds
# 0 96.88%
# 1 82.77%
# 3 82.45%
# 4 97.94%
# 5 99.09%
# === A frame took 1.906 seconds
# 0 97.95%
# 1 84.48%
# 3 51.43%
# 4 68.57%
# 5 97.97%
# 6 99.41%
# === A frame took 1.898 seconds
# 0 97.26%
# 1 83.27%
# 2 52.46%
# 3 64.70%
# 4 98.11%
# 5 99.19%
# === A frame took 1.879 seconds
# 0 97.54%
# 1 88.75%
# 3 72.44%
# 4 97.91%
# 5 99.22%
# === A frame took 1.865 seconds
# 0 97.33%
# 1 87.22%
# 3 62.10%
# 4 98.34%
# 5 99.23%
# === A frame took 1.859 seconds
# 0 97.51%
# 1 89.30%
# 3 70.86%
# 4 98.26%
# 5 99.02%
# === A frame took 1.895 seconds
# 0 97.81%
# 1 89.64%
# 3 55.82%
# 4 98.10%
# 5 98.95%
# === A frame took 1.891 seconds
# 0 97.30%
# 1 86.76%
# 3 71.90%
# 4 98.17%
# 5 98.68%
# === A frame took 1.915 seconds
# 0 96.83%
# 1 87.24%
# 3 66.64%
# 4 98.28%
# 5 98.29%
# === A frame took 1.870 seconds
# 0 96.07%
# 1 85.41%
# 3 65.70%
# 4 97.98%
# 5 97.84%
# === A frame took 1.915 seconds
# 0 97.61%
# 1 88.89%
# 2 54.51%
# 3 50.52%
# 4 98.50%
# 5 99.13%
# === A frame took 1.893 seconds
# 0 98.64%
# 1 91.03%
# 2 98.78%
# 3 99.39%
# === A frame took 1.909 seconds
# 0 98.25%
# 1 89.54%
# 2 51.74%
# 3 98.78%
# 4 99.25%
# === A frame took 1.928 seconds
# 0 98.54%
# 1 91.22%
# 2 51.29%
# 3 98.90%
# 4 99.21%
# === A frame took 1.957 seconds
# 0 98.36%
# 1 92.76%
# 2 62.39%
# 3 98.68%
# 4 99.22%
# === A frame took 1.916 seconds
# 0 98.16%
# 1 91.23%
# 2 68.89%
# 3 98.71%
# 4 99.03%
# === A frame took 1.931 seconds
# 0 98.58%
# 1 90.47%
# 2 58.25%
# 3 98.42%
# 4 99.12%
# === A frame took 1.920 seconds
# 0 98.69%
# 1 89.84%
# 2 57.99%
# 3 98.52%
# 4 99.21%
# === A frame took 1.914 seconds
# 0 98.88%
# 1 91.02%
# 2 56.07%
# 3 98.37%
# 4 99.00%
# === A frame took 1.967 seconds
# 0 99.21%
# 1 92.79%
# 2 58.01%
# 3 98.42%
# 4 99.31%
# === A frame took 1.921 seconds
# 0 99.04%
# 1 91.77%
# 2 59.36%
# 3 97.89%
# 4 99.33%
# === A frame took 1.890 seconds
# 0 99.29%
# 1 94.16%
# 2 71.98%
# 3 98.57%
# === A frame took 1.916 seconds
# 0 98.79%
# 1 92.10%
# 2 72.41%
# 3 98.54%
# 4 99.19%
# === A frame took 1.941 seconds
# 0 98.80%
# 1 90.13%
# 2 60.91%
# 3 98.34%
# 4 99.09%
# === A frame took 1.941 seconds
# 0 98.88%
# 1 92.63%
# 2 69.25%
# 3 98.25%
# 4 98.97%
# === A frame took 1.918 seconds
# 0 98.59%
# 1 89.54%
# 3 69.30%
# 4 96.77%
# 5 98.82%
# === A frame took 1.937 seconds
# 0 98.15%
# 1 86.51%
# 3 96.64%
# 4 52.95%
# 5 98.52%
# === A frame took 1.944 seconds
# --(!) No captured frame -- Break!
# elapsed time 758.911 seconds
